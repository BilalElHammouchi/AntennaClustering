# %%
import pandas as pd

df = pd.read_csv('autos.csv')
df.describe()
# Out:
#         symboling  num_of_doors  wheel_base      length       width  \
# count  193.000000    193.000000  193.000000  193.000000  193.000000
# mean     0.797927      3.160622   98.923834  174.326425   65.893782
# std      1.235582      0.989583    6.152409   12.478593    2.137795
# min     -2.000000      2.000000   86.600000  141.100000   60.300000
# 25%      0.000000      2.000000   94.500000  166.300000   64.100000
# 50%      1.000000      4.000000   97.000000  173.200000   65.400000
# 75%      2.000000      4.000000  102.400000  184.600000   66.900000
# max      3.000000      4.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  num_of_cylinders  engine_size        bore  \
# count  193.000000   193.000000        193.000000   193.000000  193.000000
# mean    53.869948  2561.507772          4.419689   128.124352    3.330622
# std      2.394770   526.700026          1.023182    41.590452    0.272385
# ...

# %%
#print(df['make'].value_counts())
make_counts = pd.DataFrame(df['make'].value_counts())
make_counts = make_counts.reset_index()

# Rename the columns appropriately
make_counts.columns = ['Make', 'Count']

# Add an ID column
#make_counts['ID'] = range(0, len(make_counts))
make_counts
# Out:
#              Make  Count
# 0          toyota     32
# 1          nissan     18
# 2           honda     13
# 3      mitsubishi     13
# 4      volkswagen     12
# 5          subaru     12
# 6           mazda     12
# 7           volvo     11
# 8          peugot     11
# 9             bmw      8
# 10          dodge      8
# 11  mercedes-benz      8
# 12       plymouth      7
# 13           saab      6
# 14           audi      6
# 15        porsche      4
# 16    alfa-romero      3
# 17         jaguar      3
# 18      chevrolet      3
# 19          isuzu      2
# 20        mercury      1

# %%
import random


df.columns[random.randint(0, len(df.columns))]

# %%
for c in df.columns:
    if df[c].dtype == 'object':
        print(df[c].value_counts())
# Out:
# toyota           32
# nissan           18
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# mazda            12
# volvo            11
# peugot           11
# bmw               8
# dodge             8
# mercedes-benz     8
# plymouth          7
# saab              6
# audi              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# mercury           1
# Name: make, dtype: int64
# gas       174
# diesel     19
# Name: fuel_type, dtype: int64
# std      158
# turbo     35
# Name: aspiration, dtype: int64
# sedan          92
# hatchback      63
# wagon          24
# hardtop         8
# convertible     6
# Name: body_style, dtype: int64
# fwd    114
# rwd     71
# 4wd      8
# Name: drive_wheels, dtype: int64
# front    190
# rear       3
# Name: engine_location, dtype: int64
# ohc     141
# ohcf     15
# ohcv     13
# dohc     12
# l        12
# Name: engine_type, dtype: int64
# ...
